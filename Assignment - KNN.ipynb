# %% [markdown]
# # Assignment - KNN

# %% [markdown]
# ### Import Libraries

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn import preprocessing
import seaborn as sns
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.model_selection import cross_val_score
sns.set()

# %% [markdown]
# ### Import Dataset

# %%
df = pd.read_csv("D:\EXCELR\DATA SCIENCE\DATA SCIENCE ASSIGNMENT\KNN pending\KNN\\Zoo.csv")
df
# Out:
#     animal name  hair  feathers  eggs  milk  airborne  aquatic  predator  \
# 0      aardvark     1         0     0     1         0        0         1
# 1      antelope     1         0     0     1         0        0         0
# 2          bass     0         0     1     0         0        1         1
# 3          bear     1         0     0     1         0        0         1
# 4          boar     1         0     0     1         0        0         1
# ..          ...   ...       ...   ...   ...       ...      ...       ...
# 96      wallaby     1         0     0     1         0        0         0
# 97         wasp     1         0     1     0         1        0         0
# 98         wolf     1         0     0     1         0        0         1
# 99         worm     0         0     1     0         0        0         0
# 100        wren     0         1     1     0         1        0         0
#
#      toothed  backbone  breathes  venomous  fins  legs  tail  domestic  \
# 0          1         1         1         0     0     4     0         0
# 1          1         1         1         0     0     4     1         0
# 2          1         1         0         0     1     0     1         0
# 3          1         1         1         0     0     4     0         0
# 4          1         1         1         0     0     4     1         0
# ..       ...       ...       ...       ...   ...   ...   ...       ...
# 96         1         1         1         0     0     2     1         0
# 97         0         0         1         1     0     6     0         0
# 98         1         1         1         0     0     4     1         0
# 99         0         0         1         0     0     0     0         0
# 100        0         1         1         0     0     2     1         0
#
#      catsize  type
# 0          1     1
# 1          1     1
# 2          0     4
# 3          1     1
# 4          1     1
# ..       ...   ...
# 96         1     1
# 97         0     6
# 98         1     1
# 99         0     7
# 100        0     2
#
# [101 rows x 18 columns]

# %% [markdown]
# ### Data understanding

# %%
df.describe()
# Out:
#              hair    feathers        eggs        milk    airborne     aquatic  \
# count  101.000000  101.000000  101.000000  101.000000  101.000000  101.000000
# mean     0.425743    0.198020    0.584158    0.405941    0.237624    0.356436
# std      0.496921    0.400495    0.495325    0.493522    0.427750    0.481335
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 50%      0.000000    0.000000    1.000000    0.000000    0.000000    0.000000
# 75%      1.000000    0.000000    1.000000    1.000000    0.000000    1.000000
# max      1.000000    1.000000    1.000000    1.000000    1.000000    1.000000
#
#          predator     toothed    backbone    breathes    venomous        fins  \
# count  101.000000  101.000000  101.000000  101.000000  101.000000  101.000000
# mean     0.554455    0.603960    0.821782    0.792079    0.079208    0.168317
# std      0.499505    0.491512    0.384605    0.407844    0.271410    0.376013
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000    0.000000    1.000000    1.000000    0.000000    0.000000
# 50%      1.000000    1.000000    1.000000    1.000000    0.000000    0.000000
# 75%      1.000000    1.000000    1.000000    1.000000    0.000000    0.000000
# max      1.000000    1.000000    1.000000    1.000000    1.000000    1.000000
#
#              legs        tail    domestic     catsize        type
# count  101.000000  101.000000  101.000000  101.000000  101.000000
# mean     2.841584    0.742574    0.128713    0.435644    2.831683
# std      2.033385    0.439397    0.336552    0.498314    2.102709
# min      0.000000    0.000000    0.000000    0.000000    1.000000
# 25%      2.000000    0.000000    0.000000    0.000000    1.000000
# 50%      4.000000    1.000000    0.000000    0.000000    2.000000
# 75%      4.000000    1.000000    0.000000    1.000000    4.000000
# max      8.000000    1.000000    1.000000    1.000000    7.000000

# %%
df.isna().sum()
# Out:
# animal name    0
# hair           0
# feathers       0
# eggs           0
# milk           0
# airborne       0
# aquatic        0
# predator       0
# toothed        0
# backbone       0
# breathes       0
# venomous       0
# fins           0
# legs           0
# tail           0
# domestic       0
# catsize        0
# type           0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 101 entries, 0 to 100
# Data columns (total 18 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   animal name  101 non-null    object
#  1   hair         101 non-null    int64
#  2   feathers     101 non-null    int64
#  3   eggs         101 non-null    int64
#  4   milk         101 non-null    int64
#  5   airborne     101 non-null    int64
#  6   aquatic      101 non-null    int64
#  7   predator     101 non-null    int64
#  8   toothed      101 non-null    int64
#  9   backbone     101 non-null    int64
#  10  breathes     101 non-null    int64
#  11  venomous     101 non-null    int64
#  12  fins         101 non-null    int64
#  13  legs         101 non-null    int64
#  14  tail         101 non-null    int64
#  15  domestic     101 non-null    int64
#  16  catsize      101 non-null    int64
#  17  type         101 non-null    int64
# dtypes: int64(17), object(1)
# memory usage: 14.3+ KB

# %%
df.shape
# Out:
# (101, 18)

# %%
df.columns
# Out:
# Index(['animal name', 'hair', 'feathers', 'eggs', 'milk', 'airborne',
#        'aquatic', 'predator', 'toothed', 'backbone', 'breathes', 'venomous',
#        'fins', 'legs', 'tail', 'domestic', 'catsize', 'type'],
#       dtype='object')

# %%
df[df.duplicated()].shape
# Out:
# (0, 18)

# %% [markdown]
# ### Data visualisation

# %%
sns.pairplot(df)
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
df.hist()
plt.show()

df.boxplot()
plt.show()

# %%
df.plot(kind='density', subplots=True, layout=(4,5), figsize=(13,20), sharex=False, sharey=False)
plt.show()

# %%
df.plot(kind='box', subplots=True, layout=(4,5), figsize=(13,20), sharex=False, sharey=False)
plt.show()

# %% [markdown]
# ### Finding correlation between the variables in the data

# %%
df.dtypes
# Out:
# animal name    object
# hair            int64
# feathers        int64
# eggs            int64
# milk            int64
# airborne        int64
# aquatic         int64
# predator        int64
# toothed         int64
# backbone        int64
# breathes        int64
# venomous        int64
# fins            int64
# legs            int64
# tail            int64
# domestic        int64
# catsize         int64
# type            int64
# dtype: object

# %%
df = df.drop('animal name', axis=1)

# %%
cor = df.corr(method='pearson')

# %%
cor.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_e8f0c_row0_col0, #T_e8f0c_row1_col1, #T_e8f0c_row2_col2, #T_e8f0c_row3_col3, #T_e8f0c_row4_col4, #T_e8f0c_row5_col5, #T_e8f0c_row6_col6, #T_e8f0c_row7_col7, #T_e8f0c_row8_col8, #T_e8f0c_row9_col9, #T_e8f0c_row10_col10, #T_e8f0c_row11_col11, #T_e8f0c_row12_col12, #T_e8f0c_row13_col13, #T_e8f0c_row14_col14, #T_e8f0c_row15_col15, #T_e8f0c_row16_col16 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_e8f0c_row0_col1, #T_e8f0c_row0_col10 {
#   background-color: #5e7de7;
#   color: #f1f1f1;
# }
# #T_e8f0c_row0_col2, #T_e8f0c_row5_col14 {
#   background-color: #4e68d8;
#   color: #f1f1f1;
# }
# #T_e8f0c_row0_col3 {
#   background-color: #cb3e38;
#   color: #f1f1f1;
# }
# #T_e8f0c_row0_col4, #T_e8f0c_row1_col12 {
#   background-color: #8caffe;
#   color: #000000;
# }
# #T_e8f0c_row0_col5, #T_e8f0c_row9_col10, #T_e8f0c_row16_col14 {
#   background-color: #5977e3;
#   color: #f1f1f1;
# }
# #T_e8f0c_row0_col6, #T_e8f0c_row2_col14 {
#   background-color: #5f7fe8;
#   color: #f1f1f1;
# }
# #T_e8f0c_row0_col7 {
#   background-color: #f7b093;
#   color: #000000;
# }
# #T_e8f0c_row0_col8, #T_e8f0c_row8_col0 {
#   background-color: #ead4c8;
#   color: #000000;
# }
# #T_e8f0c_row0_col9 {
#   background-color: #f7ba9f;
#   color: #000000;
# }
# #T_e8f0c_row0_col11 {
#   background-color: #7ea1fa;
#   color: #f1f1f1;
# }
# #T_e8f0c_row0_col12 {
#   background-color: #f4c5ad;
#   color: #000000;
# }
# #T_e8f0c_row0_col13 {
#   background-color: #c5d6f2;
#   color: #000000;
# }
# #T_e8f0c_row0_col14, #T_e8f0c_row4_col8 {
#   background-color: #bfd3f6;
#   color: #000000;
# }
# #T_e8f0c_row0_col15 {
#   background-color: #f6bfa6;
#   color: #000000;
# }
# #T_e8f0c_row0_col16, #T_e8f0c_row7_col10 {
#   background-color: #688aef;
#   color: #f1f1f1;
# }
# #T_e8f0c_row1_col0, #T_e8f0c_row3_col6 {
#   background-color: #80a3fa;
#   color: #f1f1f1;
# }
# #T_e8f0c_row1_col2, #T_e8f0c_row9_col3, #T_e8f0c_row15_col0 {
#   background-color: #f7ac8e;
#   color: #000000;
# }
# #T_e8f0c_row1_col3, #T_e8f0c_row12_col7 {
#   background-color: #94b6ff;
#   color: #000000;
# }
# #T_e8f0c_row1_col4 {
#   background-color: #f08b6e;
#   color: #f1f1f1;
# }
# #T_e8f0c_row1_col5, #T_e8f0c_row10_col7, #T_e8f0c_row14_col16 {
#   background-color: #b1cbfc;
#   color: #000000;
# }
# #T_e8f0c_row1_col6 {
#   background-color: #6c8ff1;
#   color: #f1f1f1;
# }
# #T_e8f0c_row1_col7 {
#   background-color: #3f53c6;
#   color: #f1f1f1;
# }
# #T_e8f0c_row1_col8, #T_e8f0c_row13_col7 {
#   background-color: #efcfbf;
#   color: #000000;
# }
# #T_e8f0c_row1_col9 {
#   background-color: #e8d6cc;
#   color: #000000;
# }
# #T_e8f0c_row1_col10 {
#   background-color: #536edd;
#   color: #f1f1f1;
# }
# #T_e8f0c_row1_col11, #T_e8f0c_row2_col6 {
#   background-color: #8badfd;
#   color: #000000;
# }
# #T_e8f0c_row1_col13, #T_e8f0c_row7_col15, #T_e8f0c_row9_col8, #T_e8f0c_row11_col2, #T_e8f0c_row11_col8, #T_e8f0c_row14_col3 {
#   background-color: #edd2c3;
#   color: #000000;
# }
# #T_e8f0c_row1_col14, #T_e8f0c_row16_col1 {
#   background-color: #90b2fe;
#   color: #000000;
# }
# #T_e8f0c_row1_col15, #T_e8f0c_row2_col13, #T_e8f0c_row12_col1, #T_e8f0c_row13_col6, #T_e8f0c_row14_col5, #T_e8f0c_row15_col14 {
#   background-color: #8db0fe;
#   color: #000000;
# }
# #T_e8f0c_row1_col16, #T_e8f0c_row5_col1, #T_e8f0c_row15_col6 {
#   background-color: #aec9fc;
#   color: #000000;
# }
# #T_e8f0c_row2_col0, #T_e8f0c_row2_col3, #T_e8f0c_row2_col7, #T_e8f0c_row3_col2, #T_e8f0c_row3_col10, #T_e8f0c_row5_col9, #T_e8f0c_row6_col14, #T_e8f0c_row7_col1, #T_e8f0c_row7_col4, #T_e8f0c_row8_col10, #T_e8f0c_row8_col16, #T_e8f0c_row9_col5, #T_e8f0c_row9_col11, #T_e8f0c_row11_col12, #T_e8f0c_row14_col6, #T_e8f0c_row16_col8, #T_e8f0c_row16_col13, #T_e8f0c_row16_col15 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_e8f0c_row2_col1 {
#   background-color: #f5c0a7;
#   color: #000000;
# }
# #T_e8f0c_row2_col4, #T_e8f0c_row7_col11, #T_e8f0c_row9_col12 {
#   background-color: #f2c9b4;
#   color: #000000;
# }
# #T_e8f0c_row2_col5, #T_e8f0c_row6_col5 {
#   background-color: #f4c6af;
#   color: #000000;
# }
# #T_e8f0c_row2_col8, #T_e8f0c_row5_col10, #T_e8f0c_row5_col15 {
#   background-color: #93b5fe;
#   color: #000000;
# }
# #T_e8f0c_row2_col9, #T_e8f0c_row5_col12, #T_e8f0c_row7_col2, #T_e8f0c_row15_col4 {
#   background-color: #6b8df0;
#   color: #f1f1f1;
# }
# #T_e8f0c_row2_col10, #T_e8f0c_row8_col6 {
#   background-color: #96b7ff;
#   color: #000000;
# }
# #T_e8f0c_row2_col11, #T_e8f0c_row6_col8 {
#   background-color: #d8dce2;
#   color: #000000;
# }
# #T_e8f0c_row2_col12 {
#   background-color: #88abfd;
#   color: #000000;
# }
# #T_e8f0c_row2_col15, #T_e8f0c_row12_col11 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_e8f0c_row2_col16 {
#   background-color: #eb7d62;
#   color: #f1f1f1;
# }
# #T_e8f0c_row3_col0 {
#   background-color: #cc403a;
#   color: #f1f1f1;
# }
# #T_e8f0c_row3_col1 {
#   background-color: #6282ea;
#   color: #f1f1f1;
# }
# #T_e8f0c_row3_col4 {
#   background-color: #6788ee;
#   color: #f1f1f1;
# }
# #T_e8f0c_row3_col5, #T_e8f0c_row11_col14 {
#   background-color: #6f92f3;
#   color: #f1f1f1;
# }
# #T_e8f0c_row3_col7 {
#   background-color: #f18f71;
#   color: #f1f1f1;
# }
# #T_e8f0c_row3_col8 {
#   background-color: #f7b99e;
#   color: #000000;
# }
# #T_e8f0c_row3_col9, #T_e8f0c_row15_col8 {
#   background-color: #f6bea4;
#   color: #000000;
# }
# #T_e8f0c_row3_col11, #T_e8f0c_row4_col5, #T_e8f0c_row4_col14, #T_e8f0c_row16_col6 {
#   background-color: #98b9ff;
#   color: #000000;
# }
# #T_e8f0c_row3_col12, #T_e8f0c_row8_col11, #T_e8f0c_row13_col11, #T_e8f0c_row14_col8 {
#   background-color: #dfdbd9;
#   color: #000000;
# }
# #T_e8f0c_row3_col13, #T_e8f0c_row8_col9 {
#   background-color: #e1dad6;
#   color: #000000;
# }
# #T_e8f0c_row3_col14, #T_e8f0c_row10_col11 {
#   background-color: #b3cdfb;
#   color: #000000;
# }
# #T_e8f0c_row3_col15, #T_e8f0c_row7_col0 {
#   background-color: #f6a586;
#   color: #000000;
# }
# #T_e8f0c_row3_col16 {
#   background-color: #4b64d5;
#   color: #f1f1f1;
# }
# #T_e8f0c_row4_col0 {
#   background-color: #adc9fd;
#   color: #000000;
# }
# #T_e8f0c_row4_col1 {
#   background-color: #f08a6c;
#   color: #f1f1f1;
# }
# #T_e8f0c_row4_col2, #T_e8f0c_row5_col2 {
#   background-color: #f7b497;
#   color: #000000;
# }
# #T_e8f0c_row4_col3, #T_e8f0c_row11_col0, #T_e8f0c_row15_col1 {
#   background-color: #9dbdff;
#   color: #000000;
# }
# #T_e8f0c_row4_col6 {
#   background-color: #3d50c3;
#   color: #f1f1f1;
# }
# #T_e8f0c_row4_col7 {
#   background-color: #4358cb;
#   color: #f1f1f1;
# }
# #T_e8f0c_row4_col9, #T_e8f0c_row14_col0 {
#   background-color: #ecd3c5;
#   color: #000000;
# }
# #T_e8f0c_row4_col10 {
#   background-color: #7da0f9;
#   color: #f1f1f1;
# }
# #T_e8f0c_row4_col11 {
#   background-color: #84a7fc;
#   color: #f1f1f1;
# }
# #T_e8f0c_row4_col12, #T_e8f0c_row8_col5, #T_e8f0c_row11_col3, #T_e8f0c_row14_col2 {
#   background-color: #c1d4f4;
#   color: #000000;
# }
# #T_e8f0c_row4_col13, #T_e8f0c_row10_col0, #T_e8f0c_row10_col12 {
#   background-color: #bed2f6;
#   color: #000000;
# }
# #T_e8f0c_row4_col15, #T_e8f0c_row16_col3 {
#   background-color: #5d7ce6;
#   color: #f1f1f1;
# }
# #T_e8f0c_row4_col16, #T_e8f0c_row5_col8, #T_e8f0c_row14_col9 {
#   background-color: #d4dbe6;
#   color: #000000;
# }
# #T_e8f0c_row5_col0, #T_e8f0c_row6_col4 {
#   background-color: #779af7;
#   color: #f1f1f1;
# }
# #T_e8f0c_row5_col3 {
#   background-color: #9ebeff;
#   color: #000000;
# }
# #T_e8f0c_row5_col4 {
#   background-color: #92b4fe;
#   color: #000000;
# }
# #T_e8f0c_row5_col6, #T_e8f0c_row8_col1, #T_e8f0c_row12_col16 {
#   background-color: #e3d9d3;
#   color: #000000;
# }
# #T_e8f0c_row5_col7, #T_e8f0c_row14_col12 {
#   background-color: #c7d7f0;
#   color: #000000;
# }
# #T_e8f0c_row5_col11 {
#   background-color: #f39778;
#   color: #000000;
# }
# #T_e8f0c_row5_col13, #T_e8f0c_row6_col0, #T_e8f0c_row11_col15 {
#   background-color: #b5cdfa;
#   color: #000000;
# }
# #T_e8f0c_row5_col16, #T_e8f0c_row10_col16 {
#   background-color: #f5c2aa;
#   color: #000000;
# }
# #T_e8f0c_row6_col1, #T_e8f0c_row6_col12, #T_e8f0c_row8_col14, #T_e8f0c_row10_col9 {
#   background-color: #a3c2fe;
#   color: #000000;
# }
# #T_e8f0c_row6_col2 {
#   background-color: #dadce0;
#   color: #000000;
# }
# #T_e8f0c_row6_col3, #T_e8f0c_row6_col7 {
#   background-color: #d5dbe5;
#   color: #000000;
# }
# #T_e8f0c_row6_col9 {
#   background-color: #85a8fc;
#   color: #f1f1f1;
# }
# #T_e8f0c_row6_col10, #T_e8f0c_row7_col14, #T_e8f0c_row10_col1, #T_e8f0c_row12_col14 {
#   bac

# %% [markdown]
# ### KNN

# %%
X = df.iloc[:,1:17]
y = df.iloc[:,:17]

# %%
from sklearn.preprocessing import LabelEncoder
LE = LabelEncoder()
df["catsize"] = LE.fit_transform(df["catsize"])
df["catsize"]

Y = df["catsize"]
X = df.iloc[:, 2:]
X.head()

# standardization is making our data in between -3 to +3
from sklearn.preprocessing import StandardScaler
SS = StandardScaler()
SS_X = SS.fit_transform(X)
SS_X = pd.DataFrame(SS_X)
SS_X.columns = list(X)
SS_X.head()
# Out:
#        eggs      milk  airborne   aquatic  predator   toothed  backbone  \
# 0 -1.185227  1.209717 -0.558291 -0.744208  0.896421  0.809776   0.46569
# 1 -1.185227  1.209717 -0.558291 -0.744208 -1.115547  0.809776   0.46569
# 2  0.843721 -0.826640 -0.558291  1.343710  0.896421  0.809776   0.46569
# 3 -1.185227  1.209717 -0.558291 -0.744208  0.896421  0.809776   0.46569
# 4 -1.185227  1.209717 -0.558291 -0.744208  0.896421  0.809776   0.46569
#
#    breathes  venomous      fins      legs      tail  domestic   catsize  \
# 0  0.512348 -0.293294 -0.449868  0.572540 -1.698416 -0.384353  1.138180
# 1  0.512348 -0.293294 -0.449868  0.572540  0.588784 -0.384353  1.138180
# 2 -1.951800 -0.293294  2.222876 -1.404435  0.588784 -0.384353 -0.878595
# 3  0.512348 -0.293294 -0.449868  0.572540 -1.698416 -0.384353  1.138180
# 4  0.512348 -0.293294 -0.449868  0.572540  0.588784 -0.384353  1.138180
#
#        type
# 0 -0.875451
# 1 -0.875451
# 2  0.558396
# 3 -0.875451
# 4 -0.875451

# %%
# Data partition
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test = train_test_split(SS_X,Y, test_size=0.30)

from sklearn.linear_model import LogisticRegression
logreg = LogisticRegression()

# model fitting
logreg.fit(X_train,Y_train)
Y_pred_train = logreg.predict(X_train)
Y_pred_test = logreg.predict(X_test)

from sklearn.metrics import accuracy_score
ac1 = accuracy_score(Y_train,Y_pred_train)
ac2 = accuracy_score(Y_test,Y_pred_test)
print("Training Accuracy score: ", ac1)
print("Testing Accuracy score: ", ac2)
# Out:
# Training Accuracy score:  1.0
# Testing Accuracy score:  1.0

# %%
# cross validation method
from sklearn.linear_model import LogisticRegression
logreg = LogisticRegression()
from sklearn.model_selection import train_test_split

training_accuracy = []
test_accuracy = []
for i in range(1,101):
    X_train,X_test,Y_train,Y_test = train_test_split(SS_X,Y, test_size=0.30,random_state=i)
    logreg.fit(X_train,Y_train)
    Y_pred_train = logreg.predict(X_train)
    Y_pred_test = logreg.predict(X_test)
    training_accuracy.append(accuracy_score(Y_train,Y_pred_train))
    test_accuracy.append(accuracy_score(Y_test,Y_pred_test))

print("Cross validation Training score: ", np.mean(training_accuracy).round(2))
print("Cross validation Test score: ", np.mean(test_accuracy).round(2))
# Out:
# Cross validation Training score:  1.0
# Cross validation Test score:  1.0

# %%
# KNN

from sklearn.neighbors import KNeighborsClassifier
KNN = KNeighborsClassifier(n_neighbors=5)

# model fitting
KNN.fit(X_train,Y_train)
Y_pred_train = KNN.predict(X_train)
Y_pred_test = KNN.predict(X_test)

from sklearn.metrics import accuracy_score
ac1 = accuracy_score(Y_train,Y_pred_train)
ac2 = accuracy_score(Y_test,Y_pred_test)
print("Training Accuracy score: ", ac1)
print("Testing Accuracy score: ", ac2)
# Out:
# Training Accuracy score:  0.9428571428571428
# Testing Accuracy score:  0.9354838709677419

# %%
# k = 5, with cross validation

# cross validation method
from sklearn.neighbors import KNeighborsClassifier
KNN = KNeighborsClassifier(n_neighbors=15)
from sklearn.model_selection import train_test_split

training_accuracy = []
test_accuracy = []
for i in range(1,101):
    X_train,X_test,Y_train,Y_test = train_test_split(SS_X,Y, test_size=0.30,random_state=i)
    KNN.fit(X_train,Y_train)
    Y_pred_train = KNN.predict(X_train)
    Y_pred_test = KNN.predict(X_test)
    training_accuracy.append(accuracy_score(Y_train,Y_pred_train))
    test_accuracy.append(accuracy_score(Y_test,Y_pred_test))

print("Cross validation Training score: ", np.mean(training_accuracy))
print("Cross validation Test score: ", np.mean(test_accuracy))
# Out:
# Cross validation Training score:  0.8392857142857143
# Cross validation Test score:  0.8374193548387098
